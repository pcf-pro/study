# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pylab import rcParams
import statsmodels.api as sm

# %%
import sys
import warnings
warnings.filterwarnings('ignore')
from tqdm import tqdm

import pandas as pd
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error

import statsmodels.formula.api as smf
import statsmodels.tsa.api as smt
import statsmodels.api as sm
import scipy.stats as scs
from scipy.optimize import minimize

import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('time series 1.txt')
dataset2= pd.read_csv('time series 2.txt')

# %%
dataset.head()
# Out:
#         1
# 0  1.0000
# 1 -0.3000
# 2 -1.4700
# 3 -0.2220
# 4  1.9503

# %%
plt.title('Time series', fontsize=15)
plt.plot(dataset2,'r', label='time2')
plt.plot(dataset, 'g', label='time1' )
plt.legend()
plt.show()

# %%
Анализ - графиков:
1) У графиков есть тренд
2) ряды имеют мультипликативный циклический характер 
3) выбросов нет 
4)

# %%
plt.plot(dataset.describe(), 'g', label='time1')
plt.plot(dataset2.describe(), 'r', label='time2')
plt.legend()

# %%
dataset.plot(figsize=(15,6))
dataset2.plot(figsize=(15,6))
plt.show()

# %%
otg1diff = dataset.diff(periods=1).dropna()
ig = plt.figure(figsize=(12,8))
ax1 = ig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(otg1diff.values.squeeze(), lags=25, ax=ax1)

ax2 = ig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(otg1diff, lags=25, ax=ax2)
# Out:
# C:\Users\Denis-Boss leasing\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1358: RuntimeWarning: invalid value encountered in sqrt
#   return rho, np.sqrt(sigmasq)

# %%
np.average(dataset)
# Out:
# 0.12513332452019052

# %%
np.average(dataset2)
# Out:
# 0.3135351272956922

# %%
y = dataset.copy()
x = dataset2.copy()

# %%
df = pd.concat([dataset, dataset2], axis=1)
df.plot()

# %%
row =  ['JB', 'p-value', 'skew','kurtosis']
jb_test = sm.stats.stattools.jarque_bera(dataset)
a = np.vstack([jb_test])
for i,j in zip(row,a):
    print(i,*j)
# Out:
# JB 0.15112790625233233
# p-value 0.9272204299926484
# skew 0.08463858373243167
# kurtosis 2.829947724830725
